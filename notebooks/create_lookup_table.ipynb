# %%
import pandas as pd
import pickle

# %%
from collections import namedtuple
IndexEntryCrop = namedtuple('IndexEntryCrop', ['img_path', 'sub_idx', 'crop_path_1p0', 'classname', 'left', 'top', 'right', 'bottom'], verbose=False)

# %%
FILE = '/raid/user-data/lscheucher/projects/bounding_box_classifier/full_object_index_crop.pickle'
with open(FILE, 'rb') as f:
    test = pickle.load(f)
test[0]
# Out:
# IndexEntryCrop(img_path='/raid/group-data/uc150429/AID_DATA_201803/original_image/laidy_2018-10-18T10:01:37.401839.png', sub_idx=0, crop_path_1p0='/raid/user-data/lscheucher/tmp/pytorch_classifier_data/Car/laidy_2018-10-18T10:01:370.png', classname='Car', left=874, top=591, right=926, bottom=639)

# %% [markdown]
# ## crop2sub_idx

# %%
FILE = '/raid/user-data/lscheucher/tmp/pytorch_classifier/crop2sub_idx.pickle'
with open(FILE, 'rb') as f:
    test = pickle.load(f)
test
# Out:
# {'/raid/user-data/lscheucher/tmp/pytorch_classifier_data/TrafficSign/laidy_2018-11-10T12:25:4923.png': 23,
#  '/raid/user-data/lscheucher/tmp/pytorch_classifier_data/Truck/laidy_2018-11-10T09:41:007.png': 7,
#  '/raid/user-data/lscheucher/tmp/pytorch_classifier_data/Car/laidy_2018-11-20T11:35:1513.png': 13,
#  '/raid/user-data/lscheucher/tmp/pytorch_classifier_data/Car/laidy_2018-10-08T11:12:559.png': 9,
#  '/raid/user-data/lscheucher/tmp/pytorch_classifier_data/Car/laidy_2018-10-09T11:28:523.png': 3,
#  '/raid/user-data/lscheucher/tmp/pytorch_classifier_data/Car/laidy_2018-11-20T15:08:1326.png': 26,
#  '/raid/user-data/lscheucher/tmp/pytorch_classifier_data/TrafficSign/laidy_2018-11-10T10:47:599.png': 9,
#  '/raid/user-data/lscheucher/tmp/pytorch_classifier_data/Car/laidy_2018-11-20T15:07:528.png': 8,
#  '/raid/user-data/lscheucher/tmp/pytorch_classifier_data/Car/laidy_2018-10-22T07:20:487.png': 7,
# ...

# %% [markdown]
# ## crop2img

# %%
FILE = '/raid/user-data/lscheucher/tmp/pytorch_classifier/crop2img.pickle'
with open(FILE, 'rb') as f:
    test = pickle.load(f)

[key for key,val in test.items() if 'empty' in test]
# Out:
# []
